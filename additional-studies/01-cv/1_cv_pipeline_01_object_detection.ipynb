# %% [markdown]
# ### 컴퓨터 비전 : 객체 탐지 개발 파이프라인
#
# - 이 노트북은 **`객체 탐지` 개발 파이프라인 예제 실습**을 수행하는 노트북입니다.
#
# ##### YOLO를 활용한 객체 탐지 개발 파이프라인 예제
#    1.  YOLO 학습용/검증용 데이터셋 전처리 (Cell 1개)
#    2.  YOLO Fine-Tuning 및 저장 (Cell 1개)
#    3.  Fine-tuning 한 모델의 성능 평가 (Cell 1개)

# %% [markdown]
# ### 01. YOLO 학습용/검증용 데이터셋 전처리
#
# ImageSets/Main의 trainval.txt와 test.txt 파일을 기반으로 학습용과 검증용 데이터를 분리합니다.
#
# 원본 이미지와 라벨 파일들을 YOLO 형식의 디렉토리 구조(images/train, labels/train, images/test, labels/test)로 재구성하여 이동시킵니다.
#
# * 데이터셋 루트 경로 설정 및 원본 이미지(JPEGImages), 라벨(Annotations_txt) 폴더 지정
# * 학습용과 검증용 타겟 디렉토리(images/train, images/test, labels/train, labels/test) 생성
# * trainval.txt 파일을 읽어 해당 ID의 이미지와 라벨을 train 폴더로 이동
# * test.txt 파일을 읽어 해당 ID의 이미지와 라벨을 test 폴더로 이동

# %%
# ============================================ 
# Cell 1: 데이터 전처리 실행 (선택사항)
# ============================================

# 주의: 이 셀은 kaggle Fashion Dataset이 존재하고 전처리를 진행하지 않은 경우에만 실행하세요.
# 이미 전처리 데이터로 dataset.zip의 압축을 풀어서 활용하셔도 됩니다.
# 이미 전처리된 데이터가 있다면 이 셀을 건너뛰고 Cell 2로 진행하세요.

#ImageSets/Main 내 trainval.txt와 text.txt 파일을 읽어 학습할 이미지/레이블 셋과 검증용 이미지/레이블 셋을 분리하여 파일 이동
#학습용 이미지 & 레이블 : images/train, labels/train
#검증용 이미지 & 레이블: images/test, images/test

import os
import shutil

# dataset root 경로 (작업 디렉토리에 맞게 수정)
ROOT        = "./dataset/fashion"
JPEG_DIR    = os.path.join(ROOT, "JPEGImages")      # 원본 이미지 폴더
LABELS_SRC  = os.path.join(ROOT, "Annotations_txt") # 원본 라벨 폴더
SETS_DIR    = os.path.join(ROOT, "ImageSets", "Main")
TRAIN_IDS   = os.path.join(SETS_DIR, "trainval.txt")
TEST_IDS    = os.path.join(SETS_DIR, "test.txt")

# 이동할 타겟 디렉토리
IMG_DST     = os.path.join(ROOT, "images")
LBL_DST     = os.path.join(ROOT, "labels")

# train/test 폴더 생성
for split in ("train", "test"):
    os.makedirs(os.path.join(IMG_DST, split), exist_ok=True)
    os.makedirs(os.path.join(LBL_DST, split), exist_ok=True)

def move_split(id_file, split):
    """
    id_file: trainval.txt 또는 test.txt 경로
    split:   "train" 또는 "test"
    """
    with open(id_file, "r", encoding="utf-8") as f:
        for line in f:
            idx = line.strip()
            if not idx:
                continue

            # 이미지 파일 이동
            src_img = os.path.join(JPEG_DIR, f"{idx}.jpg")
            dst_img = os.path.join(IMG_DST, split, f"{idx}.jpg")
            if os.path.exists(src_img):
                if not os.path.exists(dst_img):  # 목적지에 파일이 없을 때만 이동
                    shutil.move(src_img, dst_img)
                else:   # Source 파일과 Dest 파일이 모두 존재하면 Skip
                    print(f"Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) {idx}.jpg")
            else:
                if not os.path.exists(dst_img):  # 목적지에도 없다면 경고
                    print(f"Warning: 이미지 없음 {src_img}")
                else:   # Dest 파일이 모두 존재하면 Skip
                    print(f"Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) {idx}.jpg")

            # 라벨 파일 이동
            src_lbl = os.path.join(LABELS_SRC, f"{idx}.txt")
            dst_lbl = os.path.join(LBL_DST, split, f"{idx}.txt")
            if os.path.exists(src_lbl):
                if not os.path.exists(dst_lbl):  # 목적지에 파일이 없을 때만 이동
                    shutil.move(src_lbl, dst_lbl)
                else:   # Source 파일과 Dest 파일이 모두 존재하면 Skip
                    print(f"Skip: 이미 파일이 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) {idx}.txt")
            else:
                if not os.path.exists(dst_lbl):  # 목적지에도 없다면 경고
                    print(f"Warning: 라벨 없음 {src_lbl}")
                else:   # Dest 파일이 모두 존재하면 Skip
                    print(f"Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) {idx}.txt")

# 1) 학습용(trainval.txt) → images/train, labels/train
move_split(TRAIN_IDS, "train")
print("train split 완료")

# 2) 검증용(test.txt) → images/test, labels/test
move_split(TEST_IDS, "test")
print("test split 완료")
# Out:
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 168468.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 168468.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 20751.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 20751.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 184291.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 184291.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 63239.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 63239.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 110606.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 110606.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 31187.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 31187.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 103194.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 103194.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 137927.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 137927.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 89286.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 89286.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 46319.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 46319.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 62403.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 62403.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 53324.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 53324.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 30169.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 30169.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 185536.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 185536.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 98155.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 98155.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 175092.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 175092.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 121359.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 121359.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 50761.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 50761.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 184951.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 184951.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 81298.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 81298.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 133345.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 133345.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 47897.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 47897.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 13689.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 13689.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 120376.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 120376.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 185145.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 185145.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 88148.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 88148.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 138332.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 138332.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 124731.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 124731.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 64263.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 64263.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 102551.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 102551.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 123954.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 123954.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 83626.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 83626.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 100034.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 100034.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 13302.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 13302.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 159249.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 159249.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 110686.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 110686.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 62639.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 62639.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 53060.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 53060.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 26107.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 26107.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 115148.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 115148.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 186905.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 186905.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 17856.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 17856.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 104798.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 104798.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 14058.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 14058.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 177993.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 177993.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 30429.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 30429.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 185196.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 185196.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 23001.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 23001.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 110739.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 110739.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 191287.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 191287.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 103419.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 103419.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 165166.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 165166.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 144894.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 144894.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 87026.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 87026.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 185830.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 185830.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 73507.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 73507.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 87406.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 87406.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 177810.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 177810.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 55928.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 55928.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 84072.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 84072.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 11674.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 11674.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 27992.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 27992.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 47978.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 47978.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 105494.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 105494.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 81865.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 81865.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 12175.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 12175.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 164716.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 164716.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 88622.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 88622.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 151175.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 151175.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 2061.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 2061.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 39123.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 39123.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 41142.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 41142.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 13722.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 13722.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 90104.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 90104.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 185714.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 185714.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 92267.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 92267.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 1388.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 1388.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 88380.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 88380.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 181527.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 181527.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 187362.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 187362.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 35921.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 35921.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 80692.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 80692.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 444.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 444.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 52202.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 52202.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 176907.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 176907.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 171839.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 171839.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 62605.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 62605.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 130366.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 130366.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 47502.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 47502.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 173552.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 173552.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 82309.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 82309.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 136647.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 136647.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 42251.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 42251.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 2499.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 2499.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 15707.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 15707.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 112639.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 112639.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 190520.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 190520.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 59289.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 59289.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 31982.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 31982.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 50992.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 50992.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 48902.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 48902.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 80841.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 80841.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 81937.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 81937.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 27483.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 27483.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 2545.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 2545.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 162735.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 162735.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 116453.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 116453.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 72967.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 72967.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 171298.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 171298.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 166218.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 166218.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 22264.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 22264.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 2804.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 2804.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 38410.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 38410.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 47145.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 47145.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 172826.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 172826.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 45131.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 45131.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 191988.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 191988.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 20650.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 20650.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 180512.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 180512.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 10947.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 10947.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 28211.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 28211.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 101074.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 101074.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 187996.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 187996.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 192208.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 192208.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 184407.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 184407.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 57050.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 57050.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 87831.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 87831.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 187000.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 187000.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 101269.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 101269.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 105948.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 105948.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 183190.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 183190.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 186636.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 186636.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 111451.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 111451.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 22239.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 22239.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 186253.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 186253.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 83473.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 83473.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 29112.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 29112.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 42837.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 42837.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 186297.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 186297.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 142255.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 142255.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 104499.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 104499.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 177182.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 177182.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 70665.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 70665.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 134164.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 134164.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 44544.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 44544.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 103371.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 103371.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 99108.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 99108.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 183720.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 183720.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 150006.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 150006.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 27001.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 27001.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 132393.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 132393.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 187691.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 187691.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 183799.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 183799.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 7134.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 7134.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 147381.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 147381.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 185937.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 185937.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 11960.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 11960.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 100824.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 100824.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 139506.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 139506.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 50091.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 50091.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 42130.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 42130.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 120646.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 120646.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 79027.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 79027.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 34330.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 34330.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 15514.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 15514.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 46878.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 46878.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 164770.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 164770.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 33814.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 33814.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 45325.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 45325.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 12484.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 12484.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 97223.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 97223.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 9313.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 9313.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 146553.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 146553.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 100232.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 100232.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 29754.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 29754.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 185553.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 185553.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 137904.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 137904.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 3606.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 3606.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 84008.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 84008.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 194466.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 194466.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 104835.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 104835.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 38506.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 38506.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 117662.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 117662.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 184305.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 184305.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 98335.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 98335.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 106672.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 106672.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 66535.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 66535.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 32723.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 32723.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 10225.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 10225.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 185374.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 185374.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 185847.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 185847.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 185048.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 185048.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 97150.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 97150.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 182285.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 182285.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 103819.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 103819.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 150805.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 150805.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 181889.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 181889.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 128119.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 128119.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 80118.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 80118.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 188257.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 188257.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 39352.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 39352.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 177898.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 177898.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 72689.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 72689.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 43737.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 43737.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 169689.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 169689.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 107164.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 107164.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 10032.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 10032.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 185284.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 185284.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 73048.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 73048.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 36063.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 36063.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 43216.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 43216.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 81100.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 81100.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 59656.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 59656.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 46711.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 46711.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 158389.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 158389.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 6347.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 6347.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 105946.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 105946.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 138609.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 138609.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 86194.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 86194.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 188159.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 188159.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 137776.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 137776.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 73878.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 73878.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 130306.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 130306.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 162823.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 162823.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 189957.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 189957.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 128767.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 128767.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 130669.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 130669.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 89736.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 89736.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 77844.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 77844.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 30561.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 30561.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 29590.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 29590.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 118698.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 118698.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 144521.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 144521.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 81502.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 81502.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 79281.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 79281.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 47611.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 47611.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 190518.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 190518.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 26568.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 26568.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 153339.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 153339.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 102134.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 102134.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 185401.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 185401.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 38023.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 38023.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 28892.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 28892.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 81823.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 81823.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 16851.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 16851.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 183404.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 183404.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 67299.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 67299.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 141215.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 141215.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 138438.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 138438.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 96743.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 96743.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 104589.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 104589.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 120212.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 120212.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 169137.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 169137.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 188262.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 188262.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 188681.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 188681.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 187625.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 187625.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 68080.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 68080.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 167635.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 167635.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 62344.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 62344.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 83420.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 83420.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 30567.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 30567.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 102182.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 102182.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 132743.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 132743.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 4437.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 4437.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 130408.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 130408.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 14433.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 14433.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 51148.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 51148.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 47334.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 47334.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 46336.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 46336.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 181299.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 181299.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 89009.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 89009.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 182800.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 182800.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 106825.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 106825.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 185428.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 185428.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 108331.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 108331.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 24740.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 24740.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 49543.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 49543.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 188222.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 188222.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 50252.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 50252.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 86433.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 86433.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 13525.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 13525.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 83239.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 83239.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 111723.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 111723.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 2380.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 2380.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 64567.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 64567.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 97381.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 97381.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 83477.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 83477.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 46855.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 46855.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 46516.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 46516.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 177668.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 177668.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 97020.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 97020.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 147534.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 147534.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 45773.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 45773.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 72413.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 72413.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 192514.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 192514.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 186737.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 186737.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 51153.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 51153.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 68321.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 68321.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 10117.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 10117.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 116147.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 116147.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 187871.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 187871.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 10556.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 10556.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 14035.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 14035.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 3316.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 3316.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 191067.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 191067.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 187016.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 187016.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 162724.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 162724.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 4179.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 4179.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 108549.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 108549.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 14620.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 14620.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 114951.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 114951.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 11918.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 11918.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 21301.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 21301.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 187019.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 187019.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 179035.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 179035.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 14574.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 14574.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 89538.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 89538.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 7341.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 7341.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 39437.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 39437.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 194471.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 194471.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 163575.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 163575.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 9068.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 9068.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 53791.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 53791.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 104019.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 104019.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 47754.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 47754.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 172268.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 172268.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 182448.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 182448.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 954.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 954.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 58243.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 58243.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 53699.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 53699.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 184837.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 184837.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 178861.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 178861.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 105720.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 105720.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 162491.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 162491.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 395.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 395.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 102478.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 102478.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 64794.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 64794.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 47035.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 47035.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 157811.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 157811.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 7119.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 7119.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 79908.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 79908.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 44699.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 44699.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 83161.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 83161.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 51680.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 51680.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 2226.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 2226.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 90467.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 90467.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 129430.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 129430.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 154510.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 154510.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 186042.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 186042.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 103801.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 103801.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 118853.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 118853.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 173797.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 173797.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 113257.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 113257.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 6382.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 6382.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 106322.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 106322.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 29351.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 29351.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 159396.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 159396.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 101805.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 101805.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 52053.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 52053.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 103992.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 103992.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 114286.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 114286.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 130298.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 130298.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 60858.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 60858.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 51854.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 51854.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 48562.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 48562.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 187375.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 187375.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 102867.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 102867.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 22226.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 22226.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 25837.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 25837.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 73979.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 73979.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 187848.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 187848.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 28192.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 28192.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 96788.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 96788.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 32154.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 32154.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 146823.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 146823.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 62064.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 62064.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 190515.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 190515.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 29665.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 29665.txt
# ...
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 171738.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 171738.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 76740.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 76740.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 16325.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 16325.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 138615.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 138615.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 14672.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 14672.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 105683.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 105683.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 138546.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 138546.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 134101.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 134101.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 192306.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 192306.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 182929.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 182929.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 43799.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 43799.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 52071.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 52071.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 118582.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 118582.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 183366.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 183366.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 92467.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 92467.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 16047.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 16047.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 57846.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 57846.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 96275.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 96275.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 178131.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 178131.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 182399.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 182399.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 80439.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 80439.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 112680.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 112680.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 179920.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 179920.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 90664.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 90664.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 169988.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 169988.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 181777.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 181777.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 2128.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 2128.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 37584.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 37584.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 146679.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 146679.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 48938.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 48938.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 51583.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 51583.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 7380.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 7380.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 15030.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 15030.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 145970.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 145970.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 5731.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 5731.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 175802.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 175802.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 16975.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 16975.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 94547.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 94547.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 6476.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 6476.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 191541.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 191541.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 182750.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 182750.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 184883.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 184883.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 184021.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 184021.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 7502.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 7502.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 114166.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 114166.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 174229.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 174229.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 3085.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 3085.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 154943.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 154943.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 185581.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 185581.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 116947.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 116947.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 188895.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 188895.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 15806.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 15806.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 170021.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 170021.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 183103.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 183103.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 31069.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 31069.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 16117.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 16117.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 117336.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 117336.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 6288.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 6288.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 20526.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 20526.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 161787.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 161787.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 8805.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 8805.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 14698.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 14698.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 158318.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 158318.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 46069.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 46069.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 27621.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 27621.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 44437.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 44437.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 40949.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 40949.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 182146.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 182146.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 187833.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 187833.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 56052.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 56052.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 86522.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 86522.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 125748.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 125748.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 56322.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 56322.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 172089.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 172089.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 189227.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 189227.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 183186.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 183186.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 93855.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 93855.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 57685.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 57685.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 61494.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 61494.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 171164.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 171164.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 152726.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 152726.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 49708.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 49708.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 81466.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 81466.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 165390.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 165390.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 134423.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 134423.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 192552.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 192552.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 148300.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 148300.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 180017.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 180017.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 110249.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 110249.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 55306.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 55306.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 2459.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 2459.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 103060.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 103060.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 20871.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 20871.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 46873.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 46873.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 14606.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 14606.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 27901.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 27901.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 12459.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 12459.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 138420.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 138420.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 56922.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 56922.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 187135.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 187135.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 84523.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 84523.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 138251.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 138251.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 113476.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 113476.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 38652.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 38652.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 183225.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 183225.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 166717.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 166717.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 188932.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 188932.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 36436.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 36436.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 109746.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 109746.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 90855.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 90855.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 190772.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 190772.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 63548.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 63548.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 187530.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 187530.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 150850.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 150850.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 151212.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 151212.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 190057.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 190057.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 90852.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 90852.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 58063.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 58063.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 70633.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 70633.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 79060.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 79060.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 89667.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 89667.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 52923.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 52923.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 76241.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 76241.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 145595.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 145595.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 185303.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 185303.txt
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 2409.jpg
# Skip: 이미 이동됨 (datasets.zip 파일은 이미 전처리가 수행된 데이터셋입니다.) 2409.txt
# test split 완료

# %% [markdown]
# ### 02. YOLO Fine-Tuning 및 저장
#
# 사전학습된 YOLOv8 nano 모델(`yolov8n.pt`)을 커스텀 패션 데이터셋으로 Fine-Tuning합니다.
#
# GPU/CPU 환경을 자동 감지하고 30 에포크 동안 학습을 진행하여 최적화된 가중치를 생성합니다.
#
# * PyTorch와 Ultralytics YOLO 라이브러리 임포트 및 CUDA GPU 사용 가능 여부에 따른 디바이스 설정
# * COCO 데이터셋으로 사전학습된 YOLOv8 nano 모델 로드
# * 커스텀 패션 데이터셋(fashion.yaml)으로 10 에포크, 배치 크기 8, 이미지 크기 640×640 설정하여 학습 실행
# * 학습 완료 후 실험 결과 디렉토리와 최적 가중치(best.pt) 파일 경로 출력 및 확인

# %%
# ============================================ 
# Cell 2: YOLO Fine-Tuning 및 저장
# ============================================

import torch                   # PyTorch: 딥러닝 연산 및 GPU 사용을 위한 핵심 라이브러리
from ultralytics import YOLO   # Ultralytics YOLOv8 API: 객체 탐지 모델을 간편하게 사용
import os                      # 운영체제(OS) 경로 조작을 위한 표준 모듈
from pathlib import Path

# ─────────────────────────────────────────────────────────────────────────────
# 1) 디바이스 설정
#    torch.cuda.is_available()를 사용해 현재 환경에 CUDA GPU가 있는지 판단합니다.
#    GPU가 있으면 'cuda:0' (첫 번째 GPU), 없으면 'cpu'를 사용하도록 합니다.
#    이렇게 하면 같은 코드로 GPU/CPU 양쪽 환경 모두에서 동작합니다.
# ─────────────────────────────────────────────────────────────────────────────
device = "cuda:0" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")  # 실제로 선택된 디바이스 정보를 출력해 확인

# ─────────────────────────────────────────────────────────────────────────────
# 2) 사전학습된 YOLOv8n 모델 로드
#    "yolov8n.pt"는 Ultralytics에서 제공하는 YOLOv8 Nano 모델의 가중치 파일로,
#    COCO 데이터셋(80개 클래스)으로 미리 학습되어 있습니다.
#    이 가중치를 불러오면 객체 탐지의 기본 특성(엣지, 모양 등)을 이미 학습한 상태로 시작할 수 있습니다.
# ─────────────────────────────────────────────────────────────────────────────
model = YOLO("yolov8n.pt")

# ─────────────────────────────────────────────────────────────────────────────
# 3) 모델 학습(Fine-Tuning) 실행
#    model.train() 호출 시 주요 인자:
#      - data  : "dataset/fashion.yaml"
#                  학습/검증 이미지 경로(path, train, val)와 클래스 목록(names)이 정의된 YAML 파일
#      - epochs: 1
#                  테스트를 위해 전체 데이터셋을 1번 반복 학습합니다. 데이터 양이나 자원에 맞춰 조정 가능합니다.
#      - batch : 8
#                  한 번에 GPU 메모리에 올려 처리할 이미지 수입니다. 메모리 용량에 맞춰 변경하세요.
#      - imgsz : 640
#                  입력 이미지 크기를 640×640 픽셀로 맞춥니다. (letterbox 방식으로 패딩하여 종횡비 유지)
#                  (height, width) 튜플로 다른 비율도 지정 가능합니다.
#      - device: 위에서 결정한 'cuda:0' 또는 'cpu'
#
#    이 호출 하나로 학습(train)과 검증(val)이 자동으로 수행되며,
#    매 에포크(epoch)마다 손실, mAP, Precision, Recall 등의 지표가 콘솔에 출력됩니다.
# ─────────────────────────────────────────────────────────────────────────────
results = model.train(
    data="dataset/fashion.yaml",
    epochs=1,
    batch=8,
    imgsz=640,
    device=device
)

# ─────────────────────────────────────────────────────────────────────────────
# 4) 학습 완료 후 최적 가중치(best weights) 경로 확인
#    results.save_dir 속성에는 이번 실험의 결과가 저장된 디렉토리(Path 객체)가 들어 있습니다.
#    일반적으로 runs/detect/trainX/ 형태로 생성되며, 그 하위 weights/best.pt에 최적 가중치가 저장됩니다.
# ─────────────────────────────────────────────────────────────────────────────
runs_dir = Path("runs/detect")
run_dir = sorted(runs_dir.glob("train*"), key=os.path.getmtime)[-1]

print("Run directory:", run_dir)  # 실험 결과 폴더 위치 확인

best_weights = os.path.join(run_dir, "weights", "best.pt")
print("Training complete. Best weights saved to:", best_weights)
# Out:
# Using device: cuda:0
# Ultralytics 8.3.155  Python-3.10.18 torch-2.7.1+cu128 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6141MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=dataset/fashion.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=1, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs\detect\train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to 'C:\Users\SSAFY\AppData\Roaming\Ultralytics\Arial.ttf'...
# 100%|██████████| 755k/755k [00:00<00:00, 4.71MB/s]
# Overriding model.yaml nc=80 with nc=10
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    753262  ultralytics.nn.modules.head.Detect           [10, [64, 128, 256]]
# Model summary: 129 layers, 3,012,798 parameters, 3,012,782 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100%|██████████| 5.35M/5.35M [00:01<00:00, 4.99MB/s]
# AMP: checks passed
# train: Fast image access  (ping: 0.10.0 ms, read: 38.07.9 MB/s, size: 44.0 KB)
# train: Scanning C:\Users\SSAFY\Desktop\AI_특강\dataset\fashion\labels\train... 2145 images, 0 backgrounds, 0 corrupt: 100%|██████████| 2145/2145 [00:01<00:00, 1746.89it/s]
# train: New cache created: C:\Users\SSAFY\Desktop\AI_\dataset\fashion\labels\train.cache
# val: Fast image access  (ping: 0.20.0 ms, read: 25.213.7 MB/s, size: 41.2 KB)
# val: Scanning C:\Users\SSAFY\Desktop\AI_특강\dataset\fashion\labels\test... 537 images, 0 backgrounds, 0 corrupt: 100%|██████████| 537/537 [00:00<00:00, 972.57it/s]
# val: New cache created: C:\Users\SSAFY\Desktop\AI_\dataset\fashion\labels\test.cache
# Plotting labels to runs\detect\train\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000714, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs\detect\train
# Starting training for 1 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/1       1.1G      1.384      2.656      1.402         10        640: 100%|██████████| 269/269 [00:30<00:00,  8.89it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 34/34 [00:04<00:00,  7.67it/s]
#                    all        537       2035      0.556      0.614       0.59      0.364
#
# 1 epochs completed in 0.010 hours.
# Optimizer stripped from runs\detect\train\weights\last.pt, 6.2MB
# Optimizer stripped from runs\detect\train\weights\best.pt, 6.2MB
#
# Validating runs\detect\train\weights\best.pt...
# Ultralytics 8.3.155  Python-3.10.18 torch-2.7.1+cu128 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6141MiB)
# Model summary (fused): 72 layers, 3,007,598 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 34/34 [00:03<00:00,  9.22it/s]
#                    all        537       2035      0.555      0.614      0.591      0.364
#               sunglass         82         82      0.194      0.329      0.157     0.0418
#                    hat         77         77       0.53      0.143       0.36      0.149
#                 jacket        179        181      0.771      0.713      0.793      0.544
#                  shirt        361        366      0.668      0.609      0.668      0.435
#                  pants        114        114      0.737      0.868      0.895      0.646
#                 shorts        107        107      0.454      0.822      0.673      0.436
#                  skirt        186        186      0.492      0.785      0.533      0.382
#                  dress        128        128      0.523      0.351      0.456      0.326
#                    bag        274        274      0.505      0.726       0.62      0.298
#                   shoe        520        520      0.674      0.798       0.75      0.382
# Speed: 0.2ms preprocess, 1.5ms inference, 0.0ms loss, 1.7ms postprocess per image
# Results saved to runs\detect\train
# Run directory: runs\detect\train
# Training complete. Best weights saved to: runs\detect\train\weights\best.pt

# %% [markdown]
# ### 03. Fine-tuning 한 모델의 성능 평가
#
# 학습이 완료된 모델(`best.pt`)을 로드하여 검증 데이터셋으로 성능을 평가합니다.
#
# mAP, Precision, Recall 등의 주요 지표를 계산하고 출력하여 모델의 객체 탐지 성능을 정량적으로 분석합니다.
#
# * PyTorch와 Ultralytics YOLO 라이브러리 임포트 및 CUDA GPU 사용 가능 여부에 따른 디바이스 설정
# * 학습된 최적 가중치(best.pt) 파일을 경로 지정하여 YOLOv8 모델로 로드
# * 패션 데이터셋으로 검증 수행하여 DetMetrics 객체에서 성능 지표 추출
# * AP50, mAP@0.50-0.95, Precision, Recall 값을 계산하고 포맷팅하여 콘솔 출력

# %%
# ============================================ 
# Cell 3: Fine-tuning 한 모델의 성능 평가
# ============================================

import torch                   # PyTorch: 모델 학습·추론 및 GPU 사용을 위한 핵심 라이브러리
from ultralytics import YOLO   # Ultralytics YOLOv8 API: 객체 탐지 모델을 간편하게 불러오기
import os                      # 운영체제 경로 조작을 위한 표준 모듈

# ─────────────────────────────────────────────────────────────────────────────
# 1) 디바이스 설정
#    - torch.cuda.is_available(): CUDA 지원 GPU 사용 가능 여부 확인
#    - 'cuda:0': 첫 번째 GPU 디바이스 지정
#    - 'cpu'    : GPU가 없을 경우 CPU 사용
# ─────────────────────────────────────────────────────────────────────────────
device = "cuda:0" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

# ─────────────────────────────────────────────────────────────────────────────
# 2) 학습된 모델(best.pt) 로드
#    - YOLO(best_weights) 호출 시 해당 가중치 파일로 모델 초기화
# ─────────────────────────────────────────────────────────────────────────────
model = YOLO(best_weights)
print(f"Loaded best weights from: {best_weights}")

# ─────────────────────────────────────────────────────────────────────────────
# 3) 검증 수행 (Validation)
#    - model.val() 호출로 YAML에 정의된 검증 데이터셋 평가 실행
#    - data: 'dataset/fashion.yaml' (경로·클래스 정보 포함)
#    - imgsz: 입력 이미지 크기(px), train과 동일하게 설정
#    - batch : 배치 크기, GPU 메모리에 맞춰 조절
#    - device: 위에서 설정한 디바이스
#    반환값 metrics는 DetMetrics 객체로 다양한 지표를 포함
# ─────────────────────────────────────────────────────────────────────────────
metrics = model.val(
    data="dataset/fashion.yaml",
    imgsz=640,
    batch=8,
    device=device
)

# ─────────────────────────────────────────────────────────────────────────────
# 4) 검증 지표 추출
#    DetMetrics 객체 내부 box 속성에는 Metric 인스턴스가 있고,
#    그 안에 AP, mAP, Precision, Recall 등이 저장돼 있습니다.
#
#    - all_ap      : 클래스별 AP(10개 IoU threshold)
#    - map         : IoU 0.50:0.95 평균 mAP (COCO mAP)
#    - p, r        : 클래스별 Precision, Recall 리스트
# ─────────────────────────────────────────────────────────────────────────────

# 4.1) AP50 (IoU=0.5) 값 추출 및 클래스 평균 계산
ap50_per_class = metrics.box.all_ap[:, 0]      # AP50 배열 (클래스 수,)
mAP50 = float(ap50_per_class.mean())           # 전체 클래스 평균 AP50

# 4.2) COCO mAP (IoU 0.50~0.95 평균 AP)
mAP50_95 = float(metrics.box.map)

# 4.3) Precision, Recall 클래스 평균 계산
precision = float(sum(metrics.box.p) / len(metrics.box.p))
recall    = float(sum(metrics.box.r) / len(metrics.box.r))

# ─────────────────────────────────────────────────────────────────────────────
# 5) 결과 출력
#    포맷팅하여 주요 지표를 콘솔에 출력
# ─────────────────────────────────────────────────────────────────────────────
print("Validation results:")
print(f"  mAP@0.5       : {mAP50:.4f}")
print(f"  mAP@0.50–0.95 : {mAP50_95:.4f}")
print(f"  Precision     : {precision:.4f}")
print(f"  Recall        : {recall:.4f}")
# Out:
# Using device: cuda:0
# Loaded best weights from: runs\detect\train\weights\best.pt
# Ultralytics 8.3.155  Python-3.10.18 torch-2.7.1+cu128 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6141MiB)
# Model summary (fused): 72 layers, 3,007,598 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 301.792.7 MB/s, size: 34.8 KB)
# val: Scanning C:\Users\SSAFY\Desktop\AI_특강\dataset\fashion\labels\test.cache... 537 images, 0 backgrounds, 0 corrupt: 100%|██████████| 537/537 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 68/68 [00:03<00:00, 18.59it/s]
#                    all        537       2035      0.557      0.614       0.59      0.363
#               sunglass         82         82      0.189      0.317      0.155     0.0416
#                    hat         77         77      0.534      0.143      0.357      0.148
#                 jacket        179        181      0.782      0.713      0.793      0.544
#                  shirt        361        366      0.671      0.607      0.667      0.435
#                  pants        114        114       0.74      0.877      0.898      0.643
#                 shorts        107        107      0.457      0.826      0.674      0.436
#                  skirt        186        186      0.493      0.785      0.533      0.383
#                  dress        128        128      0.519      0.346      0.456      0.326
#                    bag        274        274      0.506      0.726       0.62      0.297
#                   shoe        520        520      0.675      0.798      0.749      0.382
# Speed: 0.3ms preprocess, 2.4ms inference, 0.0ms loss, 1.4ms postprocess per image
# Results saved to runs\detect\val
# Validation results:
#   mAP@0.5       : 0.5903
#   mAP@0.50–0.95 : 0.3635
#   Precision     : 0.5566
#   Recall        : 0.6137
